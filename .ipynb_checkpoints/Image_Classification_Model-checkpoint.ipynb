# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, models

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# %%
img_width = 180
img_height = 180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_text = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
plt.figure(figsize=(10, 10))
for image, label in data_train.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(image[i].numpy().astype("uint8"))
        plt.title(data_cat[label[i]])
        plt.axis()

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data_train
#
# NameError: name 'data_train' is not defined

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
    
    
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 model = Sequential([
# ----> 2     layers.Rescaling(1./255),
#       3     layers.Conv2D(16, 3, padding='same', activation='relu'),
#       4     layers.MaxPooling2D(),
#       5     layers.Conv2D(32, 3, padding='same', activation='relu'),
#       6     layers.MaxPooling2D(),
#       7     layers.Conv2D(64, 3, padding='same', activation='relu'),
#       8     layers.MaxPooling2D(),
#       9     layers.Flatten(),
#      10     layers.Dropout(0.2),
#      11     layers.Dense(128),
#      12     layers.Dense(len(data_cat))
#      13
#      14
#      15 ])
#
# NameError: name 'layers' is not defined

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 51s 505ms/step - accuracy: 0.0598 - loss: 4.5995 - val_accuracy: 0.3048 - val_loss: 2.6919
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.2510 - loss: 2.6184 - val_accuracy: 0.4444 - val_loss: 1.8185
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.4189 - loss: 2.0578 - val_accuracy: 0.7635 - val_loss: 1.0229
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.5599 - loss: 1.5237 - val_accuracy: 0.8661 - val_loss: 0.6257
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 153ms/step - accuracy: 0.7018 - loss: 1.0448 - val_accuracy: 0.8718 - val_loss: 0.5250
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.8021 - loss: 0.6815 - val_accuracy: 0.9316 - val_loss: 0.4633
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.8716 - loss: 0.4551 - val_accuracy: 0.9259 - val_loss: 0.4617
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.9106 - loss: 0.3329 - val_accuracy: 0.9430 - val_loss: 0.3693
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.9338 - loss: 0.2344 - val_accuracy: 0.9288 - val_loss: 0.4026
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.9463 - loss: 0.2309 - val_accuracy: 0.9345 - val_loss: 0.3772
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.9653 - loss: 0.1651 - val_accuracy: 0.9316 - val_loss: 0.4949
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.9666 - loss: 0.1529 - val_accuracy: 0.9459 - val_loss: 0.4234
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.9603 - loss: 0.1491 - val_accuracy: 0.9544 - val_loss: 0.3343
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.9623 - loss: 0.1387 - val_accuracy: 0.9544 - val_loss: 0.3592
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 153ms/step - accuracy: 0.9689 - loss: 0.1222 - val_accuracy: 0.9516 - val_loss: 0.3892
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.9694 - loss: 0.1413 - val_accuracy: 0.9430 - val_loss: 0.4385
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 154ms/step - accuracy: 0.9749 - loss: 0.1121 - val_accuracy: 0.9573 - val_loss: 0.4232
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.9711 - loss: 0.1186 - val_accuracy: 0.9544 - val_loss: 0.3584
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 153ms/step - accuracy: 0.9649 - loss: 0.1122 - val_accuracy: 0.9516 - val_loss: 0.4187
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.9772 - loss: 0.0896 - val_accuracy: 0.9573 - val_loss: 0.3354
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.9744 - loss: 0.1153 - val_accuracy: 0.9573 - val_loss: 0.3455
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 150ms/step - accuracy: 0.9784 - loss: 0.0848 - val_accuracy: 0.9573 - val_loss: 0.3903
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 152ms/step - accuracy: 0.9868 - loss: 0.0610 - val_accuracy: 0.9601 - val_loss: 0.4080
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.9825 - loss: 0.0791 - val_accuracy: 0.9544 - val_loss: 0.3917
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 151ms/step - accuracy: 0.9878 - loss: 0.0575 - val_accuracy: 0.9573 - val_loss: 0.3584

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8, 8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'], label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label = 'Validation Loss')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'], label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'], label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'Chilli.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(image)
img_bat = tf.expand_dims(img_array, 0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)], np.max(score)*100))
# Out:
# Veg/Fruit in image is chilli pepper with accuracy of 99.79
